# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi-suryawanshi1/projects/blob/main/US_Accident_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #US accident analysis

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od

download_url = 'https://www.kaggle.com/sobhanmoosavi/us-accidents'
od.download(download_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sakshisuryawanshi
# Your Kaggle Key: ··········
#   0%|          | 0.00/290M [00:00<?, ?B/s]
# ...
# 100%|██████████| 290M/290M [00:02<00:00, 131MB/s]

# %%
data_filename = '/content/us-accidents/US_Accidents_Dec20_Updated.csv'

# %% [markdown]
# #Data processing and Cleaning

# %%
import pandas as pd   #other ssimilar lib ---> dask, spark

# %%
df = pd.read_csv(data_filename)

# %%
df
# Out:
#                 ID  Severity  ... Nautical_Twilight Astronomical_Twilight
# 0              A-1         2  ...               Day                   Day
# 1              A-2         2  ...               Day                   Day
# 2              A-3         2  ...             Night                 Night
# 3              A-4         2  ...               Day                   Day
# 4              A-5         3  ...               Day                   Day
# ...            ...       ...  ...               ...                   ...
# 2906605  A-2906606         2  ...               Day                   Day
# 2906606  A-2906607         2  ...             Night                 Night
# 2906607  A-2906608         2  ...               Day                   Day
# 2906608  A-2906609         2  ...             Night                 Night
# 2906609  A-2906610         2  ...               Day                   Day
#
# [2906610 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906610 entries, 0 to 2906609
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat  ...  Wind_Speed(mph)  Precipitation(in)
# count  2.906610e+06  2.906610e+06  ...     2.599447e+06       1.605284e+06
# mean   2.288649e+00  3.653027e+01  ...     7.818111e+00       1.119459e-02
# std    5.541618e-01  5.013964e+00  ...     5.431171e+00       1.540812e-01
# min    1.000000e+00  2.455527e+01  ...     0.000000e+00       0.000000e+00
# 25%    2.000000e+00  3.366453e+01  ...     4.600000e+00       0.000000e+00
# 50%    2.000000e+00  3.609977e+01  ...     7.000000e+00       0.000000e+00
# 75%    3.000000e+00  4.037505e+01  ...     1.040000e+01       0.000000e+00
# max    4.000000e+00  4.900220e+01  ...     9.840000e+02       2.400000e+01
#
# [8 rows x 14 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                 ID  Severity  ... Nautical_Twilight Astronomical_Twilight
# 0              A-1         2  ...               Day                   Day
# 1              A-2         2  ...               Day                   Day
# 2              A-3         2  ...             Night                 Night
# 3              A-4         2  ...               Day                   Day
# 4              A-5         3  ...               Day                   Day
# ...            ...       ...  ...               ...                   ...
# 2906605  A-2906606         2  ...               Day                   Day
# 2906606  A-2906607         2  ...             Night                 Night
# 2906607  A-2906608         2  ...               Day                   Day
# 2906608  A-2906609         2  ...             Night                 Night
# 2906609  A-2906610         2  ...               Day                   Day
#
# [2906610 rows x 47 columns]>

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

num_df = df.select_dtypes(include=numerics)
len(num_df.columns)
# Out:
# 14

# %% [markdown]
# Percentage of missing values per column

# %%
# df.isna()
# df.isna().sum()
missing_percentages = df.isna().sum().sort_values(ascending=False)  / len(df)
print(missing_percentages)
# Out:
# Number                   0.650817
# Precipitation(in)        0.447713
# Wind_Chill(F)            0.407299
# Wind_Speed(mph)          0.105677
# End_Lat                  0.097303
# End_Lng                  0.097303
# Visibility(mi)           0.024798
# Weather_Condition        0.024720
# Humidity(%)              0.024520
# Temperature(F)           0.023128
# Wind_Direction           0.021838
# Pressure(in)             0.019579
# Weather_Timestamp        0.016141
# Airport_Code             0.002273
# Timezone                 0.001180
# Zipcode                  0.000383
# Nautical_Twilight        0.000038
# Astronomical_Twilight    0.000038
# Civil_Twilight           0.000038
# Sunrise_Sunset           0.000038
# City                     0.000037
# Amenity                  0.000000
# Severity                 0.000000
# Start_Time               0.000000
# End_Time                 0.000000
# Start_Lat                0.000000
# Start_Lng                0.000000
# ...

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages[missing_percentages > 0] #or != 0
# Out:
# Number                   0.650817
# Precipitation(in)        0.447713
# Wind_Chill(F)            0.407299
# Wind_Speed(mph)          0.105677
# End_Lat                  0.097303
# End_Lng                  0.097303
# Visibility(mi)           0.024798
# Weather_Condition        0.024720
# Humidity(%)              0.024520
# Temperature(F)           0.023128
# Wind_Direction           0.021838
# Pressure(in)             0.019579
# Weather_Timestamp        0.016141
# Airport_Code             0.002273
# Timezone                 0.001180
# Zipcode                  0.000383
# Nautical_Twilight        0.000038
# Astronomical_Twilight    0.000038
# Civil_Twilight           0.000038
# Sunrise_Sunset           0.000038
# City                     0.000037
# dtype: float64

# %%
missing_percentages[missing_percentages > 0].plot(kind='barh')

# %% [markdown]
# removes column that are mor than 50% from this graph. but here we'll kept it as it is

# %% [markdown]
# ## Exploratory Analysis and Visualization
# column we'll analyze:
# 1. city
# 2. Start time
# 3. Start lat, Start lng
# 4. Temperature
# 5. Weather condition

# %%
cities = df.City.unique()
len(cities)
# Out:
# 11790

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# Los Angeles            68411
# Houston                68265
# Charlotte              56176
# Miami                  49965
# Dallas                 48525
#                        ...
# Northwest Clackamas        1
# Lucan                      1
# Mount Washington           1
# Turners Falls              1
# Saulsbury                  1
# Name: City, Length: 11789, dtype: int64

# %%
cities_by_accident[:20]
# Out:
# Los Angeles      68411
# Houston          68265
# Charlotte        56176
# Miami            49965
# Dallas           48525
# Austin           38808
# Raleigh          31355
# Atlanta          29244
# Sacramento       28984
# Orlando          28092
# Nashville        25277
# Baton Rouge      25080
# Minneapolis      22469
# San Diego        22329
# Phoenix          21370
# Oklahoma City    21292
# Portland         19432
# Richmond         18343
# Seattle          17384
# Saint Paul       17266
# Name: City, dtype: int64

# %%
'New York' in df.City
# Out:
# False

# %%
'NY' in df.State
# Out:
# False

# %% [markdown]
# no. of states in US are 52 and NY is having highest population and this dataset does not contain new york

# %%
# cities_by_accident.plot(kind = 'barh')

# %%
cities_by_accident[:20].plot(kind='barh')

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
sns.distplot(cities_by_accident)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#creating 2 buckets
high_accident_cities = cities_by_accident[cities_by_accident >=1000]
low_accident_cities = cities_by_accident[cities_by_accident < 1000]

# %%
high_accident_cities
# Out:
# Los Angeles      68411
# Houston          68265
# Charlotte        56176
# Miami            49965
# Dallas           48525
#                  ...
# San Bruno         1009
# Willow Grove      1005
# Palmetto          1004
# Monterey Park     1003
# Dover             1003
# Name: City, Length: 513, dtype: int64

# %%
low_accident_cities
# Out:
# Edmond                 996
# The Dalles             996
# Selma                  994
# Royal Oak              992
# Lakeland               991
#                       ...
# Northwest Clackamas      1
# Lucan                    1
# Mount Washington         1
# Turners Falls            1
# Saulsbury                1
# Name: City, Length: 11276, dtype: int64

# %%
# perecentage having high accidents
len(high_accident_cities)/len(cities_by_accident)*100
# Out:
# 4.3515141233353125

# %%
sns.distplot(high_accident_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Summary and Conclusion
# **Insights:**
# - No data fr0m new york
# - Around 5% of the cities have more than 1000 yearly accidents.
# -The number of accidents per city decreases/increases exponentially
# - Over 1200 cities have reported just one accident (need to investigate)

# %% [markdown]
# ###Start Time

# %%
df.Start_Time
# Out:
# 0          2019-05-21 08:29:55
# 1          2019-10-07 17:43:09
# 2          2020-12-13 21:53:00
# 3          2018-04-17 16:51:23
# 4          2016-08-31 17:40:49
#                   ...
# 2906605    2018-06-28 08:49:01
# 2906606    2019-01-10 02:01:01
# 2906607    2020-11-23 12:52:00
# 2906608    2019-12-29 22:38:00
# 2906609    2018-03-26 13:35:03
# Name: Start_Time, Length: 2906610, dtype: object

# %%
print(df.Start_Time[0], type(df.Start_Time[0]),sep='\n')
# Out:
# 2019-05-21 08:29:55
# <class 'str'>

# %%
df.Start_Time = pd.to_datetime(df.Start_Time)
print(type(df.Start_Time[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
sns.histplot(df.Start_Time.dt.hour,bins=24)#why they haven't used barplot

# %%
# in percentage
#what does bins indicate
sns.distplot(df.Start_Time.dt.hour,kde= False,bins=24,norm_hist = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.Start_Time.dt.dayofweek,kde= False,bins=7,norm_hist = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Is the distribution of accidents by hour the same on weekends as on weekdays.

# %%
sundays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek==6]
sns.distplot(sundays_start_time.dt.hour,kde= False,bins=24,norm_hist = True)
#datacamp.com
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
mondays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek==0]
sns.distplot(mondays_start_time.dt.hour,kde= False,bins=24,norm_hist = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.Start_Time.dt.month,kde= False,bins=12,norm_hist = True)
#possible due to data issue JaN shows low bcz data collection started from feb 2016
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Can you explain month-wise trend of accidents?
# Much data is missing for 2016. Maybe even 2017.

# %%
df_2020 = df[df.Start_Time.dt.year== 2020]
print(sns.distplot(df_2020.Start_Time.dt.month,kde= False,bins=12,norm_hist = True))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df_2019 = df[df.Start_Time.dt.year== 2019]
print(sns.distplot(df_2019.Start_Time.dt.month,kde= False,bins=12,norm_hist = True))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df_2018 = df[df.Start_Time.dt.year== 2018]
print(sns.distplot(df_2018.Start_Time.dt.month,kde= False,bins=12,norm_hist = True))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df_2017 = df[df.Start_Time.dt.year== 2017]
print(sns.distplot(df_2017.Start_Time.dt.month,kde= False,bins=12,norm_hist = True))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df_2016 = df[df.Start_Time.dt.year== 2016]
print(sns.distplot(df_2016.Start_Time.dt.month,kde= False,bins=12,norm_hist = True))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ## Start Latitude and Longitude

# %%
#East to West --> horizontal
df.Start_Lat
# Out:
# 0          34.808868
# 1          35.090080
# 2          37.145730
# 3          39.110390
# 4          26.102942
#              ...
# 2906605    29.813824
# 2906606    34.068890
# 2906607    25.702200
# 2906608    40.660140
# 2906609    38.831749
# Name: Start_Lat, Length: 2906610, dtype: float64

# %%
#North to South --> vertical
df.Start_Lng
# Out:
# 0          -82.269157
# 1          -80.745560
# 2         -121.985052
# 3         -119.773781
# 4          -80.265091
#               ...
# 2906605    -95.399437
# 2906606   -117.342010
# 2906607    -80.335556
# 2906608   -111.952460
# 2906609   -104.748161
# Name: Start_Lng, Length: 2906610, dtype: float64

# %%
sns.scatterplot(x=df.Start_Lng, y=df.Start_Lat)

# %%
sns.scatterplot(x=df.Start_Lng, y=df.Start_Lat, size = 0.1)

# %%
sample_df = df.sample(int(0.1 * len(df)))

# %%
sns.scatterplot(x=sample_df.Start_Lng, y= sample_df.Start_Lat)

# %%
import folium

# %%
#just testing
m = folium.Map(location=[45.5236, -122.6750])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
#just testing
map = folium.Map() #gives world map
marker = folium.Marker((df.Start_Lat[0],df.Start_Lng[0]))
marker.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
for x in df[['Start_Lat','Start_Lng']].sample(100).iteritems():
  print(x)
# Out:
# ('Start_Lat', 2432087    40.987840
# 2604310    42.220594
# 1152095    30.408830
# 2316028    34.975990
# 718399     30.235229
#              ...
# 1171951    29.424000
# 5927       34.186410
# 84722      36.206554
# 1421221    38.259991
# 2656499    29.705042
# Name: Start_Lat, Length: 100, dtype: float64)
# ('Start_Lng', 2432087    -73.676470
# 2604310   -122.740191
# 1152095    -97.583860
# 2316028    -81.027924
# 718399     -85.208229
#               ...
# 1171951    -98.489014
# 5927      -118.401190
# 84722      -86.776245
# 1421221   -122.660561
# 2656499    -95.512581
# Name: Start_Lng, Length: 100, dtype: float64)

# %%
#@title Default title text
from folium import plugins
from folium.plugins import HeatMap
map = folium.Map()
sam_df = df.sample(int(0.01*len(df)))
heat_data = list(zip(list(sam_df.Start_Lat),list(sam_df.Start_Lng)))
heat_map = HeatMap(heat_data).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# - A high percentage of accidents occure betweeen 7am to 10am (probably people in hurry to get to work)
# - Next highest percentage is 3pm to 6pm
# - Count of accidents are less on weekends compare to weekdays
# - On sundays peak occurs between 10 am and 3 pm , unlike weekdays.

# %% [markdown]
# 1.Are there more accidents in warmer or colder areas?
# 2. which 5 states have the highest number of accidents? how about per capita?
# 3. Does new york show up, in the data? If yes, what is the count lower if this the most populated city
# 4. Among top 100 cities in number of accidents, which states do they belonng to most frequently?
# 5.What time of the day are accidents most frequent in? - Answered
# 6. Which days of the week has the most accidents?
# 7.Which month have the most accidents?
# 8. What is the trend of accidents year over year (decreasing / increasing)?
# 9. Which is safe state?
# 10. When is accidents of per unit traffic is highest?
# 11. Is distribution of accidents by hour the same on weekends as on weekdays?
